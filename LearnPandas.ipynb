# %% [markdown]
# <a href="https://colab.research.google.com/github/Mhmd8998/TestApp/blob/main/LearnPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

num=pd.Series(("five","six","seven","eghte"),index=("one","tow","three","four"))
num.values
# Out:
# array(['five', 'six', 'seven', 'eghte'], dtype=object)
